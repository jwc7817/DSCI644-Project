# %% [markdown]
# ### byLLM Script

# %%
import pandas

# %%
from byllm.lib import Model, by
llm = Model(model_name="gemini/gemini-2.5-flash")

# %%
@by(llm)
def clean_data(data: pd.df) -> pd.df: ...
