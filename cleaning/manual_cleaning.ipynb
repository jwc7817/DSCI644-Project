# %% [markdown]
# ## Manual Cleaning Script

# %% [markdown]
# Description here

# %% [markdown]
# #### PROMPT #X:

# %% [markdown]
# Prompt here

# %%
# code here

# %% [markdown]
# #### OUTPUT #X:

# %% [markdown]
# Output here

# %%
# code here
