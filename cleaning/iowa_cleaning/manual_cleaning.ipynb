# %% [markdown]
# ## Manual Cleaning Script

# %% [markdown]
# VERY simple cleaning script; will be expanded in Phase 3

# %%
# time tracking - START
import time
start_time = time.time()

# %%
# package imports
import numpy as np
import pandas as pd

# %%
# import data
df = pd.read_csv("../../data/iowa_liquor/iowa_liquor_sales_full.csv")
# Out:
# /var/folders/5h/d2lfn8pn1lq5vsgzkwtt18m40000gn/T/ipykernel_33912/1225136091.py:2: DtypeWarning: Columns (0: Zip Code, 1: Item Number) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../../data/iowa_liquor/iowa_liquor_sales_full.csv")

# %%
print(f"cols before: {df.shape[1]}")
# Out:
# cols before: 24

# %%
# drop all columns that are totally empty or contains just empty strings
df = df.replace("", np.nan).dropna(axis=1, how='all')

# %%
print(f"cols after: {df.shape[1]}")
# Out:
# cols after: 24

# %%
# date conversion
date_cols = ['Date']

# %%
# date conversion
for col in date_cols:
    if col in df.columns: 
        df[col] = pd.to_datetime(df[col], errors='coerce')

# %%
# boolean handling
bools = df.select_dtypes(include=['object']).columns
# Out:
# /var/folders/5h/d2lfn8pn1lq5vsgzkwtt18m40000gn/T/ipykernel_33912/2389739699.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   bools = df.select_dtypes(include=['object']).columns

# %%
# boolean handling; ensures all y/n and true/false cols are labeled as boolean
for col in bools:
    if df[col].nunique() <= 2 and 'true' in str(df[col].iloc[0]).lower(): 
        df[col] = df[col].astype(bool)

# %%
# finanical edits
financial_cols = ['State Bottle Cost', 'State Bottle Retail', 'Sale (Dollars)']

# %%
# finanical edits; make sure all "money cols" with nan are replaced with 0 to represent real life data
for col in financial_cols: 
    if col in df.columns: 
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0)

# %%
# force id and key cols to be strings to prevent leading 0s
id_cols = ['Invoice/Item Number', 'Store Number', 'Item Number', 'Vendor Number', 'County Number', 'Zip Code']

# %%
for col in id_cols:
    if col in df.columns: 
        df[col] = df[col].astype(str).str.replace('.0', '', regex=False)

# %%
df.to_csv('../../data/iowa_liquor/mt_cleaned_iowa_liquor_full.csv', index=False)

# %%
# time tracking - STOP
end_time = time.time()
duration = end_time - start_time
print(f"Execution time: {duration:.2f} seconds")
# Out:
# Execution time: 238.63 seconds
