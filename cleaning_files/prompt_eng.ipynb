# %% [markdown]
# ### Prompt Engineering Script

# %% [markdown]
# This is a "manual prompting" script to serve as a baseline for the byLLM project.
#
# Using Google Gemini's web/chat interface at gemini.google.com

# %% [markdown]
# #### PROMPT #X:
# Prompt here

# %% [markdown]
# #### PROMPT #X:
# Prompt here
